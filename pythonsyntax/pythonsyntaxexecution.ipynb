# %% [markdown]
# ## 1. Python Syntax Execution:
#
# - We can run python code on IDEs, terminal
#
# - We can create a .py file or .ipynb file to run and execute python code

# %% [markdown]
# ## 2. Python Indentation:
#
# - Python strictly follows indentation
#
# - Without proper indentation, python throws error

# %%
#python is running the code, coz of indentation before print()

if 5 > 2:
    print("five is greater than 2")

#if we dont indent, python throws error

#if 3 < 10:
#print("three is smaller than ten")


#any number of spaces is possible, but standard way is pressing tab key one time or 4 time spaces

if 5 > 2:
 print("Five is greater than two!") 
if 5 > 2:
        print("Five is greater than two!")
# Out:
# five is greater than 2
# Five is greater than two!
# Five is greater than two!

# %% [markdown]
# ## 3. Python Comments
#
# - Python has commenting capability for the purpose of in-code documentation
#
# - We use # for commenting block of code that we dont need in the program
#
# - Also # is a great way to make instructions for ourselves or for our teammates
